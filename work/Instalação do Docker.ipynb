# %% [markdown]
# # Passo 1:
#
# Faça do download do Docker Desktop em: https://docs.docker.com/desktop/windows/install/

# %% [markdown]
# # Passo 2:
#
# Instalação do Docker Desktop
#
# ![p1.jpg](attachment:p1.jpg)
#
# ![p2.jpg](attachment:p2.jpg)
#
# ![p3.jpg](attachment:p3.jpg)
#
# ![p4.jpg](attachment:p4.jpg)
#
# ![p5.jpg](attachment:p5.jpg)
#
# ![p6.jpg](attachment:p6.jpg)
#
# Após o Docker instalado, é necessário reiniciar o Windows.

# %% [markdown]
# # Passo 3:
#
# Com o Docker instalado, devemos agora instalar o WSL 2
#
# ![p7.jpg](attachment:p7.jpg)
#
# ![p8.jpg](attachment:p8.jpg)
#
# ![p9.jpg](attachment:p9.jpg)
#
# ![p10.jpg](attachment:p10.jpg)
